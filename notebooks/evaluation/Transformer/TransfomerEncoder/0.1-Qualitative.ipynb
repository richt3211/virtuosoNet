# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.neptune import get_experiment

# %%
exp = get_experiment('THESIS-36')

# %%
from src.evaluation.qualitative import TransformerEncoderQualitativeEvaluator, playMidi
from src.models.model_run_job import ModelJobParams
from src.constants import PRODUCTION_DATA_DIR, DEVELOPMENT_DATA_DIR, CACHE_MODEL_DIR
from src.models.Transformer import TransformerEncoder, TransformerEncoderHyperParams

# %%
hyper_params = TransformerEncoderHyperParams()
model = TransformerEncoder(hyper_params)

# %%
params = ModelJobParams(is_dev=False)
qualitative_evaluator = TransformerEncoderQualitativeEvaluator(params, model)

# %%
song_name = 'chopin_fantasie_impromptu'
xml_file_path = f'{PRODUCTION_DATA_DIR}/input/{song_name}/'
midi_file_path = f'{PRODUCTION_DATA_DIR}/output/{song_name}/te_bl.mid'
plot_file_path = f'{PRODUCTION_DATA_DIR}/output/{song_name}/te_bl.png'
model_path = f'{CACHE_MODEL_DIR}/transformer/transformer_encoder/v0.2_best.pth'

# %%
qualitative_evaluator.generate_performance_for_file(
    xml_file_path=xml_file_path,
    midi_file_path=midi_file_path,
    plot_path=plot_file_path,
    composer_name='Bach',
    model_path=model_path
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-53-670a7cce8f88> in <module>
#       4     plot_path=plot_file_path,
#       5     composer_name='Bach',
# ----> 6     model_path=model_path
#       7 )
#
# /uusoc/exports/scratch/rtimpson/thesis/virtuosoNet/src/evaluation/qualitative.py in generate_performance_for_file(self, xml_file_path, midi_file_path, plot_path, composer_name, model_path, tempo, mean_vel, pedal, disklavier)
#      45         prediction = torch.cat(total_output, 1)
#      46         output_midi, midi_pedals, output_features = feature_output_to_midi(prediction, note_locations, xml_doc, xml_notes, means, stds)
# ---> 47         write_midi_to_raw(midi_file_path, plot_path, output_features, output_midi, midi_pedals, pedal, disklavier )
#      48
#      49     def model_inference(self, input_x, input_y, note_locations, num_notes):
#
# /uusoc/exports/scratch/rtimpson/thesis/virtuosoNet/src/data/data_writer/data_writer.py in write_midi_to_raw(midi_path, plot_path, output_features, output_midi, midi_pedals, pedal, disklavier)
#      23
#      24 def write_midi_to_raw(midi_path, plot_path, output_features, output_midi, midi_pedals, pedal=True, disklavier=False):
# ---> 25     perf_worm.plot_performance_worm(output_features, plot_path)
#      26     print(f'Saving midi performance to {midi_path}')
#      27     xml_matching.save_midi_notes_as_piano_midi(
#
# /uusoc/exports/scratch/rtimpson/thesis/virtuosoNet/pyScoreParser/performanceWorm.py in plot_performance_worm(features, save_name)
#      70         if i > 0:
#      71             plt.plot(tempos[i-1:i+1], velocities[i-1:i+1], color=color, alpha=alpha)
# ---> 72     plt.savefig(save_name)
#      73     plt.close()
#      74
#
# /uusoc/exports/scratch/rtimpson/thesis/virtuosoNet/env/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# /uusoc/exports/scratch/rtimpson/thesis/virtuosoNet/env/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# /uusoc/exports/scratch/rtimpson/thesis/virtuosoNet/env/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# /uusoc/exports/scratch/rtimpson/thesis/virtuosoNet/env/lib/python3.7/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# /uusoc/exports/scratch/rtimpson/thesis/virtuosoNet/env/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
# --> 512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#     513
#     514     def print_to_buffer(self):
#
# /uusoc/exports/scratch/rtimpson/thesis/virtuosoNet/env/lib/python3.7/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1603         pil_kwargs.setdefault("format", format)
#    1604         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1605         image.save(fname, **pil_kwargs)
#    1606
#    1607
#
# /uusoc/exports/scratch/rtimpson/thesis/virtuosoNet/env/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2146                 fp = builtins.open(filename, "r+b")
#    2147             else:
# -> 2148                 fp = builtins.open(filename, "w+b")
#    2149
#    2150         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/uusoc/exports/scratch/rtimpson/thesis/virtuosoData/production/output/chopin_fantasie_impromptu/te_bl.png'

# %%
performance_midi = midi_file_path
score_midi = f'{DEVELOPMENT_DATA_DIR}/Bach/Fugue/bwv_858/midi_cleaned.mid'

# %%
playMidi(performance_midi)
# Out:
#                 <div id='midiPlayerDiv59224'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv59224');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
playMidi(score_midi)
# Out:
#                 <div id='midiPlayerDiv69147'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv69147');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
xml_file_path = f'{PRODUCTION_DATA_DIR}/input/bwv_858_fugue/'
midi_file_path = f'{PRODUCTION_DATA_DIR}/output/bwv_858_fugue/te_bl.mid'
plot_file_path = f'{PRODUCTION_DATA_DIR}/output/bwv_858_fugue/te_bl.png'
model_path = f'{CACHE_MODEL_DIR}/Transformer/TransformerEncoder/v0.1_best.pth'
qualitative_evaluator.generate_performance_for_file(
    xml_file_path=xml_file_path,
    midi_file_path=midi_file_path,
    plot_path=plot_file_path,
    composer_name='Bach',
    model_path=model_path
)
